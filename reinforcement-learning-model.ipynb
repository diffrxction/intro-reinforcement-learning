# %%
import os
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy

# %%
environment_name = 'CartPole-v1'
env = gym.make(environment_name)

# %%
episodes = 5
for episode in range(1, episodes+1):
    state = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action = env.action_space.sample()
        n_state, reward, done, info = env.step(action)
        score += reward
    print('Episode: {} Score: {}'.format(episode, score))
env.close()
# Out:
# Episode: 1 Score: 12.0
# Episode: 2 Score: 25.0
# Episode: 3 Score: 36.0
# Episode: 4 Score: 24.0
# Episode: 5 Score: 19.0

# %%
env.close()

# %%
log_path = os.path.join('Training', 'Logs')

# %%
env = gym.make(environment_name)
env = DummyVecEnv([lambda: env])
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, device='cpu')
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000)
# Out:
# 2022-10-25 19:13:52.796449: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-25 19:13:52.883518: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-10-25 19:13:52.901322: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-25 19:13:53.210483: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/cv2/../../lib64::/usr/lib/nvidia
# 2022-10-25 19:13:53.210528: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/cv2/../../lib64::/usr/lib/nvidia
# 2022-10-25 19:13:53.210532: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Logging to Training/Logs/PPO_8
# -----------------------------
# | time/              |      |
# |    fps             | 1931 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2248        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008107675 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.000177   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.63        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0132     |
# |    value_loss           | 52.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2421        |
# |    iterations           | 3           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007509686 |
# |    clip_fraction        | 0.0477      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.0819      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 43.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2554        |
# |    iterations           | 4           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010771619 |
# |    clip_fraction        | 0.0994      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.631      |
# |    explained_variance   | 0.239       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.5        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 56.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2257        |
# |    iterations           | 5           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.007548839 |
# |    clip_fraction        | 0.0624      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.611      |
# |    explained_variance   | 0.174       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.3        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 67.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2315         |
# |    iterations           | 6            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0120945815 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.586       |
# |    explained_variance   | 0.402        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.4         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.017       |
# |    value_loss           | 67.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2278         |
# |    iterations           | 7            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0060467217 |
# |    clip_fraction        | 0.0545       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.607       |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.48         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 45           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2358         |
# |    iterations           | 8            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0041956482 |
# |    clip_fraction        | 0.0331       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.42         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 29.9         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00666     |
# |    value_loss           | 67           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2424         |
# |    iterations           | 9            |
# |    time_elapsed         | 7            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0064904615 |
# |    clip_fraction        | 0.0347       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.563       |
# |    explained_variance   | 0.418        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.2         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00462     |
# |    value_loss           | 50           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2481         |
# |    iterations           | 10           |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0036128967 |
# |    clip_fraction        | 0.0182       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.557       |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.496        |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00291     |
# |    value_loss           | 15.4         |
# ------------------------------------------

# %%
PPO_Path = os.path.join('Training', 'Saved Models', 'PPO_Model_CartPole')
model.save(PPO_Path)

# %%
del model

# %%
model = PPO.load(PPO_Path, env=env)
model.learn(total_timesteps=10000)
# Out:
# Logging to Training/Logs/PPO_9
# -----------------------------
# | time/              |      |
# |    fps             | 1068 |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 2048 |
# -----------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 674          |
# |    iterations           | 2            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054166173 |
# |    clip_fraction        | 0.0281       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.539       |
# |    explained_variance   | 0.276        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0711       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.000837    |
# |    value_loss           | 6.35         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 630         |
# |    iterations           | 3           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008143965 |
# |    clip_fraction        | 0.0526      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.087       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.106       |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00489    |
# |    value_loss           | 4.08        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 637          |
# |    iterations           | 4            |
# |    time_elapsed         | 12           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0076440037 |
# |    clip_fraction        | 0.0412       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.527       |
# |    explained_variance   | 0.556        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0866       |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00415     |
# |    value_loss           | 2.47         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 5            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0041282717 |
# |    clip_fraction        | 0.0268       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.516       |
# |    explained_variance   | 0.041        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0806       |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00202     |
# |    value_loss           | 1.5          |
# ------------------------------------------

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
# Out:
# /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# (500.0, 0.0)

# %%
env.close()

# %%
episodes = 5
for episode in range(1, episodes+1):
    obs = env.reset()
    done = False
    score = 0

    while not done:
        env.render()
        action, states = model.predict(obs)
        obs, reward, done, info = env.step(action)
        score += reward
    print('Episode: {} Score: {}'.format(episode, score))
# Out:
# Episode: 1 Score: [500.]
# Episode: 2 Score: [500.]
# Episode: 3 Score: [500.]
# Episode: 4 Score: [500.]
# Episode: 5 Score: [500.]

# %%
env.close()

# %%
training_log_path = os.path.join(log_path, 'PPO_7')
training_log_path
# Out:
# 'Training/Logs/PPO_7'

# %%
# !tensorboard --logdir={training_log_path}
# Out:
# 2022-10-25 19:16:30.299265: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-25 19:16:30.373965: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-10-25 19:16:30.392462: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-10-25 19:16:30.694376: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/cv2/../../lib64::/usr/lib/nvidia
# 2022-10-25 19:16:30.694422: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/cv2/../../lib64::/usr/lib/nvidia
# 2022-10-25 19:16:30.694426: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2022-10-25 19:16:31.165908: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:980] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-25 19:16:31.199425: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/cv2/../../lib64::/usr/lib/nvidia
# 2022-10-25 19:16:31.199451: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1934] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
#
# NOTE: Using experimental fast data loading logic. To disable, pass
#     "--load_fast=false" and report issues on GitHub. More details:
#     https://github.com/tensorflow/tensorboard/issues/4784
#
# Serving TensorBoard on localhost; to expose to the network, use a proxy or pass --bind_all
# TensorBoard 2.10.1 at http://localhost:6006/ (Press CTRL+C to quit)
# ^C

# %%
from stable_baselines3.common.callbacks import EvalCallback, StopTrainingOnRewardThreshold

# %%
save_path = os.path.join('Training', 'Saved')

# %%
stop_callback = StopTrainingOnRewardThreshold(reward_threshold=500, verbose=1)
eval_callback = EvalCallback(env,
                             callback_on_new_best=stop_callback,
                             eval_freq=10000,
                             best_model_save_path=save_path,
                             verbose=1)

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, device='cpu')
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_10
# -----------------------------
# | time/              |      |
# |    fps             | 5896 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3660        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008566307 |
# |    clip_fraction        | 0.0881      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.687      |
# |    explained_variance   | 0.00232     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.46        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0143     |
# |    value_loss           | 56.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3350        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008315025 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.0432      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.9        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0165     |
# |    value_loss           | 41.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3289        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010400479 |
# |    clip_fraction        | 0.087       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.637      |
# |    explained_variance   | 0.229       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 56.8        |
# -----------------------------------------
# /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=316.60 +/- 141.14
# Episode length: 316.60 +/- 141.14
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 317         |
# |    mean_reward          | 317         |
# | time/                   |             |
# |    total_timesteps      | 10000       |
# | train/                  |             |
# |    approx_kl            | 0.009095959 |
# |    clip_fraction        | 0.0738      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.269       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 63.1        |
# -----------------------------------------
# New best mean reward!
# ------------------------------
# | time/              |       |
# |    fps             | 3035  |
# |    iterations      | 5     |
# |    time_elapsed    | 3     |
# |    total_timesteps | 10240 |
# ------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3036         |
# |    iterations           | 6            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0059991824 |
# |    clip_fraction        | 0.0714       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.597       |
# |    explained_variance   | 0.519        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 24.3         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 60.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3029         |
# |    iterations           | 7            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0058536814 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | 0.701        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.7         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00967     |
# |    value_loss           | 48           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3038        |
# |    iterations           | 8           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.006633425 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.586      |
# |    explained_variance   | 0.45        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.34        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00971    |
# |    value_loss           | 62.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3039         |
# |    iterations           | 9            |
# |    time_elapsed         | 6            |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057416223 |
# |    clip_fraction        | 0.0363       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.572       |
# |    explained_variance   | 0.59         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16           |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00604     |
# |    value_loss           | 59.9         |
# ------------------------------------------
# Eval num_timesteps=20000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.013524633 |
# |    clip_fraction        | 0.0988      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.843       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.7         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00735    |
# |    value_loss           | 29.1        |
# -----------------------------------------
# New best mean reward!
# Stopping training because the mean reward 500.00  is above the threshold 500

# %%
net_arch = [dict(pi=[128, 128, 128, 128], vf=[128, 128, 128, 128])]

# %%
model = PPO('MlpPolicy', env, verbose=1, tensorboard_log=log_path, device='cpu', policy_kwargs={'net_arch': net_arch})
# Out:
# Using cpu device

# %%
model.learn(total_timesteps=20000, callback=eval_callback)
# Out:
# Logging to Training/Logs/PPO_11
# -----------------------------
# | time/              |      |
# |    fps             | 3707 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1786        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.012913896 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.682      |
# |    explained_variance   | -0.000897   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.95        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1667        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.018197745 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.647      |
# |    explained_variance   | 0.41        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.36        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 27.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1612        |
# |    iterations           | 4           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.012544129 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.599      |
# |    explained_variance   | 0.351       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 16.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0246     |
# |    value_loss           | 43.6        |
# -----------------------------------------
# /home/diffract/Desktop/GitHub/intro-reinforcement-learning/.venv/lib/python3.10/site-packages/stable_baselines3/common/evaluation.py:65: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# Eval num_timesteps=10000, episode_reward=262.40 +/- 50.34
# Episode length: 262.40 +/- 50.34
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 262          |
# |    mean_reward          | 262          |
# | time/                   |              |
# |    total_timesteps      | 10000        |
# | train/                  |              |
# |    approx_kl            | 0.0076834452 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.574       |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19           |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0159      |
# |    value_loss           | 42.3         |
# ------------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1510  |
# |    iterations      | 5     |
# |    time_elapsed    | 6     |
# |    total_timesteps | 10240 |
# ------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1511        |
# |    iterations           | 6           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014911855 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.563      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 17.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1489        |
# |    iterations           | 7           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008644577 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.544      |
# |    explained_variance   | 0.844       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 18.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1489        |
# |    iterations           | 8           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015757501 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.528      |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.87        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 9.4         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1482        |
# |    iterations           | 9           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012469778 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.522      |
# |    explained_variance   | 0.984       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.28        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 7.45        |
# -----------------------------------------
# Eval num_timesteps=20000, episode_reward=500.00 +/- 0.00
# Episode length: 500.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 500         |
# |    mean_reward          | 500         |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.006886217 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.383       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00459    |
# |    value_loss           | 8.32        |
# -----------------------------------------
# ------------------------------
# | time/              |       |
# |    fps             | 1440  |
# |    iterations      | 10    |
# |    time_elapsed    | 14    |
# |    total_timesteps | 20480 |
# ------------------------------

# %%
from stable_baselines3 import DQN

# %%
model = DQN('MlpPolicy', env, verbose=1, tensorboard_log=log_path)
# Out:
# Using cuda device

# %%
model.learn(total_timesteps=20000)
# Out:
# Logging to Training/Logs/DQN_1
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.956    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 9391     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 93       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.917    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 10645    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 174      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.865    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 11090    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 284      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.833    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 11227    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 352      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.782    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 11780    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.735    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 11128    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 558      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.676    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 11232    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 682      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.627    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 11155    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.589    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 11171    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 865      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.539    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 11087    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 971      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.486    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 11203    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1082     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.434    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 11422    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1191     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.374    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 11669    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1318     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.342    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 11733    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1385     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.3      |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 11858    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1473     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.257    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 12031    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1564     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.223    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 12144    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1635     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.181    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 12325    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.147    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 12466    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1796     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.0994   |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 12710    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1896     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 13073    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2032     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 13443    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2163     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 13737    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2267     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 14046    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 14350    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2476     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 14536    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2545     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 14786    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2639     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 14963    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2712     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 15159    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2793     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 15362    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2881     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 15578    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 2972     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 15769    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3061     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 16042    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3181     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 16172    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3247     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 16333    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3326     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 16648    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3472     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 16811    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3561     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 17117    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3720     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 17272    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3823     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 17226    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3911     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 16946    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 3978     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 16467    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4028     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 15490    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4117     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 14316    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4254     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 13596    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4344     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 12679    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4415     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 12248    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4484     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 11507    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4582     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 11119    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4684     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 10845    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 10552    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4832     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 10262    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 4925     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 10063    |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5008     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 9894     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5071     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 9694     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5149     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 9408     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5273     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 9170     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5373     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 8898     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5522     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 8793     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5587     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 8691     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5660     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 8564     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5729     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 8392     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5853     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 8242     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 5954     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 8056     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6084     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 7946     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6224     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 7841     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6300     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 7686     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6356     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 7612     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6452     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 7536     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6518     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 7463     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6604     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 7399     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6689     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 7352     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6753     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 7301     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6831     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 7215     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6923     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 7150     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 6999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 7067     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7103     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 6985     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7210     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 6937     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7254     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 6901     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7316     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 6848     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7441     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 6812     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7517     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 6780     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 6747     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7643     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 6688     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7698     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 6652     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 6580     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7872     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 6514     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 7969     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 6466     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8064     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 6382     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8154     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 6321     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8219     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 6262     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8280     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 6174     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8362     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 6113     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8466     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 6074     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8554     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 6037     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8631     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 6006     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8842     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 6002     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 8974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 6014     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9066     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 6038     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9159     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 6070     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9275     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 6090     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9361     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 6071     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9420     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 6045     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9482     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 6014     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9588     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 5987     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9672     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 5966     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9759     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 5925     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 5902     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 9889     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 5870     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10000    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 5842     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10066    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 5810     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 5782     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 5757     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10355    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 5738     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 5716     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 5697     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10640    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 5684     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10748    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 5665     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10831    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 5636     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 10925    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 5608     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 11096    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 5589     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11185    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 5571     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11247    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 5556     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11309    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 5544     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11423    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 5526     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11505    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 5505     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11595    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 5491     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 5477     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11713    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 5462     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11817    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 5442     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11913    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 5427     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 11993    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 5412     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12121    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 5397     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12231    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 5386     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12295    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 5375     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 5356     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12425    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 5344     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12479    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 5328     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12541    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 5315     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12661    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 5304     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12800    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 5298     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12884    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 5291     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 12964    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 5289     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13155    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 5278     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13264    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 5262     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 5245     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13471    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 5234     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13537    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 5223     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13658    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 5210     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13750    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 5194     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13818    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 5183     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 13910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 5173     |
# |    time_elapsed     | 2        |
# |    total_timesteps  | 14015    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# ...
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 5028     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15682    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 5022     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15775    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 5019     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15844    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 5016     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15921    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 5010     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 15996    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 5003     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16085    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 4997     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16158    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 4990     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16292    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 4983     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16366    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 4977     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16455    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 4969     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16540    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 4964     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16649    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 4962     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16709    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 740      |
# |    fps              | 4957     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16791    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 744      |
# |    fps              | 4931     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16868    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 748      |
# |    fps              | 4916     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 16963    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 752      |
# |    fps              | 4904     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17019    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 756      |
# |    fps              | 4895     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17115    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 760      |
# |    fps              | 4889     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17243    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 764      |
# |    fps              | 4884     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17304    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 768      |
# |    fps              | 4883     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17418    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 772      |
# |    fps              | 4881     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17514    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 776      |
# |    fps              | 4879     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17587    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 780      |
# |    fps              | 4874     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17673    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 784      |
# |    fps              | 4873     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17769    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 788      |
# |    fps              | 4872     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17840    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 792      |
# |    fps              | 4868     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17915    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 796      |
# |    fps              | 4860     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 17981    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 800      |
# |    fps              | 4862     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 804      |
# |    fps              | 4860     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18192    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 808      |
# |    fps              | 4855     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18254    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 812      |
# |    fps              | 4849     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18347    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 4844     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18475    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 4842     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18543    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 4840     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18627    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 4839     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18715    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 4837     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18813    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 4830     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 18923    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 4827     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19002    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 4823     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19093    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 4818     |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 19226    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 4816     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19310    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 4814     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19387    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 4813     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19472    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 4809     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19525    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 4805     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19599    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 4804     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19706    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 4802     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19788    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 4799     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19848    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 4781     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 888      |
# |    fps              | 4766     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 19962    |
# ----------------------------------
